# %% [markdown]
# <a href="https://colab.research.google.com/github/khshohelrana/Thesis_Purpose_Model/blob/main/yolov8_image_object_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics -q
# !pip install pyyaml -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.0/882.0 kB 19.4 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
import yaml
import cv2
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#YOLO11n
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 114MB/s]

# %%
model.predict("/content/car_and_dog.jpg" , save = True , save_txt = True)
# Out:
# image 1/1 /content/car_and_dog.jpg: 640x640 1 car, 1 dog, 302.6ms
# Speed: 15.9ms preprocess, 302.6ms inference, 27.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 1 label saved to runs/detect/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 85,  64,  96],
#          [ 92,  69, 101],
#          [ 84,  60,  92],
#          ...,
#          [117, 103, 114],
#          [162, 152, 164],
#          [165, 155, 167]],
#
#         [[ 98,  75, 107],
#          [ 96,  72, 104],
#          [ 94,  67, 100],
#          ...,
#          [120, 107, 115],
#          [157, 147, 159],
#          [167, 157, 169]],
#
#         [[ 70,  43,  76],
#          [ 68,  39,  72],
#          [ 67,  36,  69],
#          ...,
#          [119, 106, 114],
#          [157, 147, 159],
#          [153, 145, 156]],
#
#         ...,
#
#         [[ 83,  91, 128],
#          [144, 149, 188],
#          [100,  99, 141],
#          ...,
#          [ 67,  71, 112],
#          [ 69,  73, 114],
#          [ 82,  84, 125]],
#
#         [[ 90,  97, 136],
#          [ 80,  82, 123],
#          [ 61,  58, 103],
#          ...,
#          [ 67,  69, 110],
#          [ 58,  60, 101],
#          [ 50,  52,  93]],
#
#         [[ 84,  88, 129],
#          [ 61,  60, 102],
#          [ 50,  45,  90],
#          ...,
#          [ 80,  79, 121],
#          [ 68,  70, 111],
#          [ 60,  62, 103]]], dtype=uint8)
#  orig_shape: (512, 512)
#  path: '/content/car_and_dog.jpg'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 15.864372253417969, 'inference': 302.6318550109863, 'postprocess': 27.228116989135742}]

# %%
file_name = "/content/runs/coco.yaml"
with open(file_name , "r") as stream:
  names = yaml.safe_load(stream)["names"]

# %%
names
# Out:
# {0: 'person',
#  1: 'bicycle',
#  2: 'car',
#  3: 'motorcycle',
#  4: 'airplane',
#  5: 'bus',
#  6: 'train',
#  7: 'truck',
#  8: 'boat',
#  9: 'traffic light',
#  10: 'fire hydrant',
#  11: 'stop sign',
#  12: 'parking meter',
#  13: 'bench',
#  14: 'bird',
#  15: 'cat',
#  16: 'dog',
#  17: 'horse',
#  18: 'sheep',
#  19: 'cow',
#  20: 'elephant',
#  21: 'bear',
#  22: 'zebra',
#  23: 'giraffe',
#  24: 'backpack',
#  25: 'umbrella',
#  26: 'handbag',
#  27: 'tie',
#  28: 'suitcase',
#  29: 'frisbee',
#  30: 'skis',
#  31: 'snowboard',
#  32: 'sports ball',
#  33: 'kite',
#  34: 'baseball bat',
#  35: 'baseball glove',
#  36: 'skateboard',
#  37: 'surfboard',
#  38: 'tennis racket',
#  39: 'bottle',
#  40: 'wine glass',
#  41: 'cup',
#  42: 'fork',
#  43: 'knife',
#  44: 'spoon',
#  45: 'bowl',
#  46: 'banana',
#  47: 'apple',
#  48: 'sandwich',
#  49: 'orange',
#  50: 'broccoli',
#  51: 'carrot',
#  52: 'hot dog',
#  53: 'pizza',
#  54: 'donut',
#  55: 'cake',
#  56: 'chair',
#  57: 'couch',
#  58: 'potted plant',
#  59: 'bed',
#  60: 'dining table',
#  61: 'toilet',
#  62: 'tv',
#  63: 'laptop',
#  64: 'mouse',
#  65: 'remote',
#  66: 'keyboard',
#  67: 'cell phone',
#  68: 'microwave',
#  69: 'oven',
#  70: 'toaster',
#  71: 'sink',
#  72: 'refrigerator',
#  73: 'book',
#  74: 'clock',
#  75: 'vase',
#  76: 'scissors',
#  77: 'teddy bear',
#  78: 'hair drier',
#  79: 'toothbrush'}

# %%
lis = open("/content/runs/detect/predict/labels/car_and_dog.txt" , "r").readlines()

# %%
lis
# Out:
# ['2 0.479262 0.578243 0.95793 0.529086\n',
#  '16 0.346053 0.237492 0.169154 0.21887\n']

# %%
for l in lis:
  ind = int(l.split()[0])
  print(ind , names[ind])
# Out:
# 2 car
# 16 dog

# %%
float("0.21875\n")
# Out:
# 0.21875

# %%
li = lis[0].split()
xc , yc , nw , nh = float(li[1]) , float(li[2]) , float(li[3]) , float(li[4])

# %%
img = cv2.imread("/content/car_and_dog.jpg")
h , w = img.shape[0] , img.shape[1]

# %%
xc *= w
yc *= h
nw *= w
nh *= h
top_left = (int(xc - nw/2) , int(yc - nh/2))
bottom_right = (int(xc + nw/2) , int(yc + nh/2))

# %%
top_left , bottom_right
# Out:
# ((0, 160), (490, 431))

# %%
img = cv2.rectangle(img , top_left , bottom_right , (0 , 255 , 0) , 3)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
model.predict("/content/doggo.jpg" , save = True , save_txt = True)
# Out:
# image 1/1 /content/doggo.jpg: 480x640 1 bicycle, 1 car, 1 truck, 1 dog, 136.4ms
# Speed: 7.5ms preprocess, 136.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict
# 2 labels saved to runs/detect/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[ 50,  58,  57],
#          [ 51,  59,  58],
#          [ 53,  61,  60],
#          ...,
#          [ 47,  89, 142],
#          [ 41,  50,  88],
#          [ 47,  71,  63]],
#
#         [[ 51,  59,  58],
#          [ 51,  59,  58],
#          [ 52,  60,  59],
#          ...,
#          [ 37,  74, 124],
#          [ 41,  50,  84],
#          [ 46,  70,  58]],
#
#         [[ 51,  59,  58],
#          [ 51,  59,  58],
#          [ 52,  60,  59],
#          ...,
#          [ 25,  54,  98],
#          [ 48,  54,  77],
#          [ 43,  62,  45]],
#
#         ...,
#
#         [[179, 168, 160],
#          [179, 168, 160],
#          [182, 171, 163],
#          ...,
#          [ 64,  64,  80],
#          [ 36,  39,  53],
#          [ 48,  53,  62]],
#
#         [[180, 169, 161],
#          [179, 168, 160],
#          [175, 164, 156],
#          ...,
#          [ 61,  61,  79],
#          [ 37,  40,  54],
#          [ 52,  56,  67]],
#
#         [[176, 165, 157],
#          [178, 167, 159],
#          [172, 161, 153],
#          ...,
#          [ 62,  62,  80],
#          [ 33,  36,  50],
#          [ 35,  39,  50]]], dtype=uint8)
#  orig_shape: (576, 768)
#  path: '/content/doggo.jpg'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 7.509469985961914, 'inference': 136.4307403564453, 'postprocess': 1.1589527130126953}]

# %%
model.predict("/content/runs/yolo1.jpg" , save = True , save_txt = True)
# Out:
# image 1/1 /content/runs/yolo1.jpg: 448x640 3 persons, 1 car, 132.4ms
# Speed: 4.8ms preprocess, 132.4ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 3 labels saved to runs/detect/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[210, 193, 174],
#          [210, 193, 174],
#          [210, 193, 174],
#          ...,
#          [245, 226, 199],
#          [245, 226, 199],
#          [245, 226, 199]],
#
#         [[210, 193, 174],
#          [210, 193, 174],
#          [210, 193, 174],
#          ...,
#          [245, 226, 199],
#          [245, 226, 199],
#          [245, 226, 199]],
#
#         [[210, 193, 174],
#          [210, 193, 174],
#          [210, 193, 174],
#          ...,
#          [245, 226, 199],
#          [245, 226, 199],
#          [245, 226, 199]],
#
#         ...,
#
#         [[ 14,  24,  34],
#          [ 13,  23,  33],
#          [ 15,  25,  35],
#          ...,
#          [116, 140, 164],
#          [105, 131, 155],
#          [108, 134, 158]],
#
#         [[ 23,  33,  43],
#          [ 21,  31,  41],
#          [ 22,  32,  42],
#          ...,
#          [121, 145, 169],
#          [ 84, 110, 134],
#          [ 49,  75,  99]],
#
#         [[ 47,  57,  67],
#          [ 41,  51,  61],
#          [ 37,  47,  57],
#          ...,
#          [146, 170, 194],
#          [151, 177, 201],
#          [ 91, 117, 141]]], dtype=uint8)
#  orig_shape: (853, 1280)
#  path: '/content/runs/yolo1.jpg'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 4.764795303344727, 'inference': 132.37500190734863, 'postprocess': 1.1038780212402344}]
